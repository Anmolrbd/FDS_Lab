# %% [markdown]
# <a href="https://colab.research.google.com/github/Anmolrbd/FDS_Lab/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Get acquainted with data science tools and perform statistical analysis**

# %%
import numpy as np
a = np.array([1,2,3,4])
print(a)
print(type(a))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
import math as m
pivalue = m.pi
a = m.sin((pivalue/180) * 45)
print(a)
# Out:
# 0.7071067811865475

# %%
def divide(a, b):
    if b == 0:
        raise ZeroDivisionError("Division by zero is not allowed.")
    return a / b

try:
    print(divide(10, 2))
except ZeroDivisionError as e:
    print("Caught an error:", e)
# Out:
# 5.0

# %%
import numpy as np
my_matrix = [[1,2,3],[4,5,6],[7,8,9]]
my_matrix
np.array(my_matrix)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 8, 9]])
